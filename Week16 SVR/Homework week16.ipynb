# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# ข้อที่ 1
df = pd.read_csv('output.csv')
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
# ข้อที่ 2

# %%
df.head(10)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00   490000.0       2.0       1.00          880      6380
# 6  2014-05-02 00:00:00   335000.0       2.0       2.00         1350      2560
# 7  2014-05-02 00:00:00   482000.0       4.0       2.50         2710     35868
# 8  2014-05-02 00:00:00   452500.0       3.0       2.50         2430     88426
# 9  2014-05-02 00:00:00   640000.0       4.0       2.00         1520      6200
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.tail(10)
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4590  2014-07-08 00:00:00  380680.555556       4.0       2.50         2620
# 4591  2014-07-08 00:00:00  396166.666667       3.0       1.75         1880
# 4592  2014-07-08 00:00:00  252980.000000       4.0       2.50         2530
# 4593  2014-07-08 00:00:00  289373.307692       3.0       2.50         2538
# 4594  2014-07-09 00:00:00  210614.285714       3.0       2.50         1610
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4590      8331     2.0           0     0          3        2620
# ...

# %%
df.sample(10)
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 4382  2014-05-12 00:00:00        0.0       5.0       4.50         4630
# 536   2014-05-12 00:00:00   630000.0       4.0       2.00         1770
# 1225  2014-05-23 00:00:00   556000.0       5.0       2.50         3840
# 4141  2014-07-08 00:00:00   469950.0       4.0       2.75         2530
# 15    2014-05-02 00:00:00   242500.0       3.0       1.50         1200
# 2256  2014-06-10 00:00:00   199500.0       3.0       1.00          920
# 4575  2014-07-02 00:00:00        0.0       5.0       6.25         8020
# 880   2014-05-19 00:00:00  1405000.0       4.0       3.50         3410
# 2829  2014-06-19 00:00:00   703000.0       3.0       2.00         1360
# 2067  2014-06-06 00:00:00   600000.0       4.0       2.50         2560
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4382      6324     2.0           0     0          3        3210
# ...

# %%
# ข้อที่ 3
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
# ข้อที่ 4
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.103478  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.159990  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
# ข้อที่ 5
sns.pairplot(df)

# %%
# ข้อที่ 6
fig = plt.figure(figsize=(6,4))
sns.distplot(df['price'])

# %%
fig = plt.figure(figsize=(6,4))
sns.distplot(df['bedrooms'])

# %%
fig = plt.figure(figsize=(6,4))
sns.distplot(df['bathrooms'])

# %%
fig = plt.figure(figsize=(6,4))
sns.distplot(df['sqft_lot'])

# %%
fig = plt.figure(figsize=(6,4))
sns.distplot(df['floors'])

# %%
fig = plt.figure(figsize=(6,4))
sns.distplot(df['sqft_above'])

# %%
fig = plt.figure(figsize=(6,4))
sns.distplot(df['yr_built'])

# %%
# ข้อที่ 7
df.corr()
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot    floors  \
# price          1.000000  0.200336   0.327110     0.430322  0.050451  0.151461
# bedrooms       0.200336  1.000000   0.545920     0.594876  0.068819  0.177895
# bathrooms      0.327110  0.545920   1.000000     0.760952  0.107837  0.486428
# sqft_living    0.430322  0.594876   0.760952     1.000000  0.210642  0.344512
# sqft_lot       0.050451  0.068819   0.107837     0.210642  1.000000  0.003750
# floors         0.151461  0.177895   0.486428     0.344512  0.003750  1.000000
# waterfront     0.135648 -0.003483   0.076232     0.117643  0.017241  0.022024
# view           0.228504  0.111028   0.211960     0.311103  0.073907  0.031211
# condition      0.034915  0.025080  -0.119994    -0.062560  0.000558 -0.275013
# sqft_above     0.367570  0.484705   0.689918     0.876592  0.216455  0.522814
# sqft_basement  0.210427  0.334165   0.298020     0.446417  0.034842 -0.255510
# ...

# %%
fig = plt.figure(figsize=(12,8))
sns.heatmap(df.corr())

# %%
# ข้อที่8
fig = plt.figure(figsize=(12,8))
sns.scatterplot(data = df,x='sqft_living',y='sqft_above')

# %%
# ข้อที่ 9
fig = plt.figure(figsize=(8,8))
sns.scatterplot(data = df,x='yr_built',y='yr_renovated')

# %%
# ข้อที่ 10
plt.hist(df['price'])
plt.show()

# %%
# ข้อที่ 11
fig = plt.figure(figsize=(12,8))
sns.boxplot(df['price'],orient='v')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
# ข้อที่ 12
x = df['sqft_living']
y = df['price']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=100)

# %%
x_train = np.array(x_train).reshape(-1,1)
x_test = np.array(x_test).reshape(-1,1)
y_train = np.array(y_train).reshape(-1,1)
y_test = np.array(y_test).reshape(-1,1)

# %%
# ข้อที่ 13
from sklearn.preprocessing import StandardScaler
sc_x = StandardScaler()
sc_y = StandardScaler()

x_train = sc_x.fit_transform(x_train)
y_train = sc_y.fit_transform(y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-81eade16d00e> in <module>
#       4 sc_y = StandardScaler()
#       5
# ----> 6 x_train = sc_x.fit_transform(x_train)
#       7 y_train = sc_y.fit_transform(y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
#     669     def partial_fit(self, X, y=None):
#
# ...

# %%
# ข้อที่ 14
from sklearn.svm import SVR
regressor_linear = SVR(kernel = 'linear')
regressor_linear.fit(x_train,y_train)

regressor_rbf = SVR(kernel = 'rbf')
regressor_rbf.fit(x_train,y_train)

# %%
# ข้อที่ 15 and ข้อที่ 16
predicted_linear = regressor_linear.predict(x_test)
predicted_linear

print('MAE: ', metrics.mean_absolute_error(y_test, predicted_linear))
print('MSE: ', metrics.mean_squared_error(y_test, predicted_linear))
print('RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, predicted_linear)))


predicted_rbf = regressor_rbf.predict(x_test)
print('LINEAR VS RBF')
print('MAE: ', metrics.mean_absolute_error(y_test, predicted_rbf))
print('MSE: ', metrics.mean_squared_error(y_test, predicted_rbf))
print('RMSE: ', np.sqrt(metrics.mean_squared_error(y_test,predicted_rbf)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-cce5a5d298bb> in <module>
#       1 # ข้อที่ 15 and ข้อที่ 16
# ----> 2 predicted_linear = regressor_linear.predict(x_test)
#       3 predicted_linear
#       4
#       5 print('MAE: ', metrics.mean_absolute_error(y_test, predicted_linear))
#
# NameError: name 'regressor_linear' is not defined

# %%
# ข้อที่ 17
x2 = df['sqft_living']
y2 = df['price']

x_train,x_test,y_train,y_test = train_test_split(x2,y2,test_size=0.2,random_state=100)
x_train = np.array(x_train).reshape(-1,1)
x_test = np.array(x_test).reshape(-1,1)

lm_simple = LinearRegression()
lm_simple.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x3 = df[['bedrooms','bathrooms','sqft_living','sqft_above']]
y3 = df['price']

x_train2,x_test2,y_train2,y_test2 = train_test_split(x3,y3,test_size=0.2,random_state=100)

lm_mutiple = LinearRegression()
lm_mutiple.fit(x_train2,y_train2)
# Out:
# LinearRegression()

# %%
#ข้อที่18
predicted_simple = lm_simple.predict(x_test)

print('MAE: ', metrics.mean_absolute_error(y_test, predicted_simple))
print('MSE: ', metrics.mean_squared_error(y_test, predicted_simple))
print('RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, predicted_simple)))
# Out:
# MAE:  178188.80191936935
# MSE:  76848771301.19504
# RMSE:  277216.1093825448

# %%
predicted_multi = lm_mutiple.predict(x_test2)

print('MAE: ', metrics.mean_absolute_error(y_test2, predicted_multi))
print('MSE: ', metrics.mean_squared_error(y_test2, predicted_multi))
print('RMSE: ', np.sqrt(metrics.mean_squared_error(i, predicted_multi)))
# Out:
# MAE:  175305.50726117485
# MSE:  76434905580.00095
# RMSE:  276468.6339894653

# %%
# ข้อที่19
print('RMSE SVR Linear: ', np.sqrt(metrics.mean_squared_error(y_test, predicted_linear)))
print('RMSE SVR RBF: ', np.sqrt(metrics.mean_squared_error(y_test,predicted_rbf)))
print('RMSE LR Linear: ', np.sqrt(metrics.mean_squared_error(y_test, predicted_simple)))
print('RMSE LR Mutiple: ', np.sqrt(metrics.mean_squared_error(y_test2, predicted_multi)))

print('RMSE LR Mutiple มีค่า Error ดีที่สุดคือ', np.sqrt(metrics.mean_squared_error(y_test2, predicted_multi)))
# Out:
# RMSE SVR Linear:  664313.7940301351
# RMSE SVR RBF:  665030.5797907077
# RMSE LR Linear:  277216.1093825448
# RMSE LR Mutiple:  276468.6339894653
# RMSE LR Mutiple มีค่า Error ดีที่สุดคือ 276468.6339894653

# %%
# ข้อที่ 20
fig = plt.figure(figsize=(10, 8))
plt.scatter(x_test, y_test, color = 'blue', label = 'data')
plt.plot(x_test, lm_simple.predict(x_test), color = 'red', label = 'Simple Linear Regression')
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.legend()

# %%
x_train = np.array(x_train).reshape(-1,1)
x_test = np.array(x_test).reshape(-1,1)
y_train = np.array(y_train).reshape(-1,1)
y_test = np.array(y_test).reshape(-1,1)
sc_x = StandardScaler()
sc_y = StandardScaler()

x_train = sc_x.fit_transform(x_train)
y_train = sc_y.fit_transform(y_train)
regressor_linear = SVR(kernel = 'linear')
regressor_linear.fit(x_train,y_train)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR(kernel='linear')

# %%
X_test_transform = sc_x.transform(x_test)
y_test_transform = sc_y.transform(y_test)

fig = plt.figure(figsize=(10, 8))
plt.scatter(sc_x.inverse_transform(X_test_transform), sc_y.inverse_transform(y_test_transform), color = 'red')
plt.plot(sc_x.inverse_transform(X_test_transform), sc_y.inverse_transform(regressor_linear.predict(X_test_transform)), color = 'blue')
plt.title('SVR')
plt.xlabel('sqft_living')
plt.ylabel('price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-25-db4937775d75> in <module>
# ----> 1 X_test_transform = sc_x.transform(x_test)
#       2 y_test_transform = sc_y.transform(y_test)
#       3
#       4 fig = plt.figure(figsize=(10, 8))
#       5 plt.scatter(sc_x.inverse_transform(X_test_transform), sc_y.inverse_transform(y_test_transform), color = 'red')
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X, copy)
#     786             Copy the input X or not.
#     787         """
# --> 788         check_is_fitted(self)
#     789
#     790         copy = copy if copy is not None else self.copy
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ...
